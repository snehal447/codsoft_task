# %%
#importing libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # step 1 : load the data

# %%
#Loading the data
data=pd.read_csv('Advertising.csv')
data
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %% [markdown]
# # step 2 : Domain analysis

# %% [markdown]
# ## based on different attributes make a model that predict the sales

# %% [markdown]
# # description about columns :
# ###  1)TV	:-Amount spend on TV advertisment.
# ###  2)Radio	:-Amount spend on Radio.
# ###  3)Newspaper	:-Amount spend on Newspaper
# ###  4)Sales:- Sales of product

# %%
# basic information

# %%
data.head() # print first five rows
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
data.tail() # print last five rows
# Out:
#         TV  Radio  Newspaper  Sales
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4

# %%
data.describe()
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   15.130500
# std     85.854236   14.846809   21.778621    5.283892
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   11.000000
# 50%    149.750000   22.900000   25.750000   16.000000
# 75%    218.825000   36.525000   45.100000   19.050000
# max    296.400000   49.600000  114.000000   27.000000

# %%
## 1)The distribution of TV advertismenthave more spread as compared to others.
## 2)In once case the company has spend 0 dollars for advertising on Radio.
## 3)The cost of advertisment on radio is less while for TV is high.

# %%
data.info()
# No missing values in the data.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   Radio      200 non-null    float64
#  2   Newspaper  200 non-null    float64
#  3   Sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %% [markdown]
# # step 3 : Exploratory Data Analysis(EDA)

# %%
data.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
#S Univariate Analysis

#Analyzing TV
sns.displot(x=data.TV,kde=True)

# %%
# Analyszing Radio
sns.histplot(x=data.Radio,kde=True)
# Out:
# <Axes: xlabel='Radio', ylabel='Count'>

# %%
# Aanalyzing Newspaper
sns.histplot(x=data.Newspaper,kde=True)
# By looking at below plot we can say that there are less than 10 months when the marketing cost was high
# Out:
# <Axes: xlabel='Newspaper', ylabel='Count'>

# %%
#  Bivariate Analysis
# This step is performed when inputs and output are known.
# 1st variable will be Inputs
# 2nd variable will be output/target variable.

# %%
data.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
# Analyzing TV and Sales
sns.relplot(x='TV',y='Sales',data=data)
# The more marketing on TV is leading to more sales in the product.

# %%
plt.plot(data.TV)
plt.plot(data.Sales)

# %%
# Analyzing Radio and Sales
sns.relplot(x='Radio',y='Sales',data=data)
# Radio advertisments are not showing much trend for the sales of product.

# %%
# Analyzing Newsapaper and Sales
sns.relplot(x='Newspaper',y='Sales',data=data)
# Newspaper advertisments are not showing much trend for the sales of product.

# %%
##  Multivariate Analysizing
sns.pairplot(data)

# %% [markdown]
# # step 4 : Data Preprocessing and Feature Engineering

# %%
#  1.cheking for missing values
data.isnull().sum()
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %%
# 2. cheking for duplicate data
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [TV, Radio, Newspaper, Sales]
# Index: []

# %%
# handle duplicates
data.drop_duplicates(inplace=True) # simply drop duplicate rows

# %%
# 3. Checking the outlier
sns.boxplot(x='TV',data=data)
# Out:
# <Axes: xlabel='TV'>

# %%
sns.boxplot(x='Radio',data=data)
# Out:
# <Axes: xlabel='Radio'>

# %%
sns.boxplot(x='Newspaper',data=data)
# Out:
# <Axes: xlabel='Newspaper'>

# %% [markdown]
# # step 5 :Feature Selection

# %%
data.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
##  Checking the correlation
sns.heatmap(data.drop('Sales',axis=1).corr(),annot=True)
# Out:
# <Axes: >

# %%
data.corr()
# Out:
#                  TV     Radio  Newspaper     Sales
# TV         1.000000  0.054809   0.056648  0.901208
# Radio      0.054809  1.000000   0.354104  0.349631
# Newspaper  0.056648  0.354104   1.000000  0.157960
# Sales      0.901208  0.349631   0.157960  1.000000

# %% [markdown]
# # step 6 : Model Creation

# %%
data.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
# Independent and dependent variable creation
X=data[['TV','Radio','Newspaper']] ## X variable contains all inputs
y=data.Sales ## y is output

# %%
y
# Out:
# 0      22.1
# 1      10.4
# 2      12.0
# 3      16.5
# 4      17.9
#        ...
# 195     7.6
# 196    14.0
# 197    14.8
# 198    25.5
# 199    18.4
# Name: Sales, Length: 200, dtype: float64

# %%
# Traning and testing data creation
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=4)

# %%
y_train
# Out:
# 26     15.0
# 134    10.8
# 180    15.5
# 158     7.3
# 189     6.7
#        ...
# 104    20.7
# 129     9.7
# 183    26.2
# 174    16.5
# 122    16.6
# Name: Sales, Length: 160, dtype: float64

# %% [markdown]
# # 1.linear regression

# %%
# Creating model
from sklearn.linear_model import LinearRegression
LR=LinearRegression() 
LR.fit(X_train,y_train) 
y_predict=LR.predict(X_test)

# %%
LR.coef_
# Out:
# array([0.05492414, 0.10330839, 0.00115301])

# %%
LR.intercept_
# Out:
# 4.57649714966038

# %%
y_test # Actual values
# Out:
# 11     17.4
# 99     17.2
# 128    24.7
# 175    27.0
# 1      10.4
# 111    21.8
# 90     11.2
# 177    11.7
# 88     12.9
# 187    17.3
# 61     24.2
# 199    13.4
# 191     9.9
# 123    15.2
# 184    17.6
# 188    15.9
# 33     17.4
# 171    14.5
# 138     9.6
# 84     21.7
# 81     12.3
# 102    14.8
# 147    25.4
# 34      9.5
# 47     23.2
# 124    19.7
# 112    14.1
# 6      11.8
# 14     19.0
# 190    10.8
# 80     11.8
# 18     11.3
# 167    12.2
# 45     14.9
# 153    19.0
# 119     6.6
# 100    11.7
# 83     13.6
# 181    12.2
# 71     12.4
# Name: Sales, dtype: float64

# %%
y_predict # Values predicted by model
# Out:
# array([18.85272242, 16.36312339, 21.74208484, 24.88496644, 11.13264174,
#        21.80412938, 12.4697427 , 14.77097657, 12.14529345, 18.05843504,
#        23.40251181, 18.2228724 ,  9.84591806, 14.92642582, 20.75130186,
#        21.72505269, 21.23086123, 15.82531564,  9.637559  , 20.78403264,
#        18.21341551, 21.03432919, 23.04723644,  9.98590098, 22.06142612,
#        20.60400085, 15.82038418, 11.15024588, 19.23839783, 10.99866269,
#        11.55674727, 10.51616943, 16.4943805 , 16.55447197, 18.12981319,
#         7.32067179, 17.29327111, 12.97157856, 17.16687868, 12.12102774])

# %%
#  Model Evalution
from sklearn.metrics import r2_score,mean_squared_error,mean_absolute_error
r2score=r2_score(y_test,y_predict)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
import math


print("R2 Score is:", r2score)

# Calculate adjusted R2 score 
adjusted_r2 = 1 - (1 - r2score) * (40 - 1) / (40 - 3 - 1)
print("Adjusted R2:", adjusted_r2)

# Calculate mean squared error and root mean squared error
mse = mean_squared_error(y_test, y_predict)
print("Mean Squared Error:", mse)

rmse = math.sqrt(mse)
print("Root Mean Squared Error:", rmse)

# Calculate mean absolute error
mae = mean_absolute_error(y_test, y_predict)
print("Mean Absolute Error:", mae)
# Out:
# R2 Score is: 0.9046414171169503
# Adjusted R2: 0.8966948685433629
# Mean Squared Error: 2.0189265528796407
# Root Mean Squared Error: 1.420889352792694
# Mean Absolute Error: 1.1051124490475204

# %% [markdown]
# # 2.decision tree

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.tree import plot_tree
# Initialize the Decision Tree Regressor
dt_model = DecisionTreeRegressor(max_depth=4, random_state=42)  

# Fit the model 
dt_model.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(max_depth=4, random_state=42)

# %%
# Predict on the test set
y_pred = dt_model.predict(X_test)

# %%
r2score=r2_score(y_test,y_pred)
print("R2 Score is:", r2score)
# Calculate adjusted R2 score 
adjusted_r2 = 1 - (1 - r2score) * (40 - 1) / (40 - 3 - 1)
print("Adjusted R2:", adjusted_r2)

# Calculate mean squared error and root mean squared error
mse = mean_squared_error(y_test, y_pred)
print("Mean Squared Error:", mse)

rmse = math.sqrt(mse)
print("Root Mean Squared Error:", rmse)

# Calculate mean absolute error
mae = mean_absolute_error(y_test, y_pred)
print("Mean Absolute Error:", mae)
# Out:
# R2 Score is: 0.8846778514340422
# Adjusted R2: 0.8750676723868791
# Mean Squared Error: 2.4415940425676004
# Root Mean Squared Error: 1.5625600924660787
# Mean Absolute Error: 1.2180636366557418

# %% [markdown]
# # 3. Random forest

# %%
from sklearn.ensemble import RandomForestRegressor
# Initialize the Random Forest Regressor
rf_model = RandomForestRegressor(n_estimators=100, random_state=42, max_depth=5)  

# Fit the model 
rf_model.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_depth=5, random_state=42)

# %%
# Predict on the test set
y_prediction = rf_model.predict(X_test)

# %%
r2score=r2_score(y_test,y_prediction)
print("R2 Score is:", r2score)
# Calculate adjusted R2 score 
adjusted_r2 = 1 - (1 - r2score) * (40 - 1) / (40 - 3 - 1)
print("Adjusted R2:", adjusted_r2)

# Calculate mean squared error and root mean squared error
mse = mean_squared_error(y_test, y_prediction)
print("Mean Squared Error:", mse)

rmse = math.sqrt(mse)
print("Root Mean Squared Error:", rmse)

# Calculate mean absolute error
mae = mean_absolute_error(y_test, y_prediction)
print("Mean Absolute Error:", mae)
# Out:
# R2 Score is: 0.9315739795498681
# Adjusted R2: 0.9258718111790237
# Mean Squared Error: 1.4487118560065424
# Root Mean Squared Error: 1.2036244663542455
# Mean Absolute Error: 0.9253589732727286

# %% [markdown]
#  conclusion :
#  # 1.. Linear Regression :
# R2 Score is: 0.9046414171169503
# Adjusted R2: 0.8966948685433629
# Mean Squared Error: 2.0189265528796407
# Root Mean Squared Error: 1.420889352792694
# Mean Absolute Error: 1.1051124490475204
#
#  # 2.Decision Tree :
# R2 Score is: 0.8846778514340422
# Adjusted R2: 0.8750676723868791
# Mean Squared Error: 2.4415940425676004
# Root Mean Squared Error: 1.5625600924660787
# Mean Absolute Error: 1.2180636366557418
#
#  # 3. Random Forest :
# R2 Score is: 0.9315739795498681
# Adjusted R2: 0.9258718111790237
# Mean Squared Error: 1.4487118560065424
# Root Mean Squared Error: 1.2036244663542455
# Mean Absolute Error: 0.9253589732727286

# %% [markdown]
# # 1. Linear Regression
# ## R² Score: 0.90 — Indicates a strong linear relationship between advertising budgets and sales.
# ## Adjusted R²: 0.89 — Accounts for the number of predictors, confirming a good fit.
# ## MSE, RMSE, MAE: These metrics are reasonable but show slightly higher errors compared to the Random Forest model.
# ## conclusion : Linear regression performs well but may not capture non-linear relationships between variables.
#
# # 2. Decision Tree
# ## R² Score: 0.88 — Slightly lower than Linear Regression, indicating a less accurate fit.
# ## Adjusted R²: 0.87 — Confirms that the model's performance is slightly lower.
# ## MSE, RMSE, MAE: Higher errors compared to both Linear Regression and Random Forest.
# ## conclusion: The Decision Tree model overfits the data due to its inherent nature, leading to slightly worse performance on unseen data.
#
# # 3. Random Forest
# ## R² Score: 0.93 — The highest among the models, indicating the best fit.
# ## Adjusted R²: 0.92 — Confirms that Random Forest explains the variance better than other models.
# ## MSE, RMSE, MAE: Lowest errors, demonstrating better accuracy and robustness.
# ## conclusion : Random Forest outperforms both Linear Regression and Decision Tree by capturing non-linear relationships and reducing overfitting.
#
#
# ## Best Model: Random Forest is the most suitable model for this dataset as it provides the highest accuracy and the lowest error metrics.

# %%
import pandas as pd

# Metrics data
metrics = {
    'Model': ['Linear Regression', 'Decision Tree', 'Random Forest'],
    'R2 Score': [0.9046, 0.8847, 0.9316],
    'Adjusted R2': [0.8967, 0.8751, 0.9259],
    'MSE': [2.0189, 2.4416, 1.4487],
    'RMSE': [1.4209, 1.5626, 1.2036],
    'MAE': [1.1051, 1.2181, 0.9254],
}

# Convert to DataFrame
df_metrics = pd.DataFrame(metrics)

# %%
# Plot R2 Score and Adjusted R2
plt.figure(figsize=(10, 6))
sns.barplot(data=df_metrics.melt(id_vars='Model', value_vars=['R2 Score', 'Adjusted R2']),
            x='Model', y='value', hue='variable', palette='viridis')

plt.title('R2 Score and Adjusted R2 Comparison', fontsize=16)
plt.ylabel('Score')
plt.xlabel('Model')
plt.legend(title='Metrics')
plt.ylim(0.85, 1)  
plt.show()

# %%
# Plot MSE, RMSE, and MAE
plt.figure(figsize=(12, 6))
sns.barplot(data=df_metrics.melt(id_vars='Model', value_vars=['MSE', 'RMSE', 'MAE']),
            x='Model', y='value', hue='variable', palette='coolwarm')

plt.title('Error Metrics Comparison', fontsize=16)
plt.ylabel('Error Value')
plt.xlabel('Model')
plt.legend(title='Metrics')
plt.ylim(0, 3)  
plt.show()
